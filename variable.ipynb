# %% [markdown]
# #Variable:a name or letter  which value can change
# #Rules for variables
# 1.never start with no.
# 2.no space between variable
# 3.no special character can be used
# 3.underscore can be used
# 4.donot use  "or' ,otherwise it will become string
# 5.the memory aloocation is according to the  no. in python
# 6.id tell sthe memory allocation of no.

# %%
a=10
b=10
print(a,b)
print(id(a),id(b))
print('a',b)
c="hello"
print(c)

a_b=20
print(a_b)

#a@=3
#a b=20
#@a=3
#1a=5
# Out:
# 10 10
# 140737026761928 140737026761928
# a 10
# hello
# 20
